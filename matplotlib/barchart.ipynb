# %% [markdown]
# """
# @Author: Prayag Bhoir
# @Date: 12-08-2024
# @Last Modified by: Prayag Bhoir
# @Last Modified time: 12-08-2024
# @Title : Python programs on matplotlib barchart
# """

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1. Write a Python programming to display a bar chart of the popularity of programming Languages.
# Sample data:<br>
# Programming languages: Java, Python, PHP, JavaScript, C#, C++<br>
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
def main():
	languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
	popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

	plt.figure(figsize=(10, 6))
	plt.bar(languages, popularity, color='pink')

	plt.title('Popularity of Programming Languages')
	plt.xlabel('Programming Languages')
	plt.ylabel('Popularity (%)')


	plt.show()
if __name__=='__main__':
	main()

# %% [markdown]
# ## 2. Write a Python programming to display a horizontal bar chart of the popularity of programming Languages.
# Sample data:<br>
# Programming languages: Java, Python, PHP, JavaScript, C#, C++<br>
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
def main():
	languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
	popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

	plt.figure(figsize=(10, 6))
	plt.barh(languages, popularity, color='pink')

	plt.title('Popularity of Programming Languages')
	plt.ylabel('Programming Languages')
	plt.xlabel('Popularity (%)')


	plt.show()
if __name__=='__main__':
	main()

# %% [markdown]
# ## 3. Write a Python programming to display a bar chart of the popularity of programming Languages. Use uniform color.
# Sample data:<br>
# Programming languages: Java, Python, PHP, JavaScript, C#, C++<br>
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
def main():
	languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
	popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

	plt.figure(figsize=(10, 6))
	plt.bar(languages, popularity, color='skyblue')

	plt.title('Popularity of Programming Languages')
	plt.xlabel('Programming Languages')
	plt.ylabel('Popularity (%)')


	plt.show()
if __name__=='__main__':
	main()

# %% [markdown]
# ## 4. Write a Python programming to display a bar chart of the popularity of programming Languages. Use different color for each bar.
# Sample data:<br>
# Programming languages: Java, Python, PHP, JavaScript, C#, C++<br>
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
def main():
	languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
	popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
	colors = ['red', 'blue', 'green', 'orange', 'purple', 'cyan']


	plt.figure(figsize=(10, 6))
	plt.bar(languages, popularity, color=colors)

	plt.title('Popularity of Programming Languages')
	plt.xlabel('Programming Languages')
	plt.ylabel('Popularity (%)')


	plt.show()
if __name__=='__main__':
	main()

# %% [markdown]
# ## 5. Write a Python programming to display a bar chart of the popularity of programming Languages. Attach a text label above each bar displaying its popularity (float value).
# Sample data:<br>
# Programming languages: Java, Python, PHP, JavaScript, C#, C++<br>
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
def main():
	languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
	popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

	plt.figure(figsize=(10, 6))
	bars = plt.bar(languages, popularity, color='skyblue')

	plt.title('Popularity of Programming Languages')
	plt.xlabel('Programming Languages')
	plt.ylabel('Popularity (%)')

	# for bar in bars:
	# 	yval = bar.get_height()
	# 	plt.text(
	# 		bar.get_x() + bar.get_width() / 2,  # X position (center of the bar)
  #     yval,  # Y position (top of the bar)
  #     f'{yval:.1f} %',  # Text label (popularity value formatted to one decimal place)
  #     ha='center',  # Horizontal alignment
  #     va='bottom'  # Vertical alignment
	# 	)
	plt.bar_label(bars,labels=[f"{s} %" for s in popularity])
	plt.show()
if __name__=='__main__':
	main()

# %% [markdown]
# ## 6. Write a Python programming to display a bar chart of the popularity of programming Languages. Make blue border to each bar.

# %%
def main():
	languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
	popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

	plt.figure(figsize=(10, 6))
	bars = plt.bar(languages, popularity, color='skyblue',edgecolor='blue')

	plt.title('Popularity of Programming Languages')
	plt.xlabel('Programming Languages')
	plt.ylabel('Popularity (%)')

	plt.bar_label(bars,labels=[f"{s} %" for s in popularity])
	plt.show()
if __name__=='__main__':
	main()

# %% [markdown]
# ## 7. Write a Python programming to display a bar chart of the popularity of programming Languages. Specify the position of each bar plot.
# Sample data:<br>
# Programming languages: Java, Python, PHP, JavaScript, C#, C++<br>
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
def main():
	languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
	popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
	positions = [9, 1.5, 3, 4.5, 6, 7.5] 

	plt.figure(figsize=(10, 6))
	bars = plt.bar(positions,popularity, color='skyblue',edgecolor='blue')
	plt.xticks(positions,languages)

	plt.title('Popularity of Programming Languages')
	plt.xlabel('Programming Languages')
	plt.ylabel('Popularity (%)')

	plt.bar_label(bars,labels=[f"{s} %" for s in popularity])
	plt.show()
if __name__=='__main__':
	main()

# %% [markdown]
# ## 8. Write a Python programming to display a bar chart of the popularity of programming Languages. Select the width of each bar and their positions.

# %%
def main():
	languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
	popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
	positions = [2,3,4,1,5,6] 

	plt.figure(figsize=(10, 6))
	bars = plt.bar(positions, popularity, color='skyblue',edgecolor='blue',width=np.random.random(6))
	plt.xticks(positions,languages,rotation=45) # for showing langages at x axis
	plt.yticks(rotation=90)

	plt.title('Popularity of Programming Languages')
	plt.xlabel('Programming Languages')
	plt.ylabel('Popularity (%)')

	plt.bar_label(bars,labels=[f"{s} %" for s in popularity])#for labels
	plt.show()
if __name__=='__main__':
	main()
