# %% [markdown]
# """<br>
#     @Author: Prayag Bhoir<br>
#     @Date: 13-08-2024 <br>
#     @Last Modified by: Prayag Bhoir<br>
#     @Last Modified time: 16-08-2024 <br>
#     @Title : Python program on seaborn<br>
# """

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Write a program to draw bar plot of sex against survived for a dataset given in the url

# %%
def main():
  url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
  df = pd.read_csv(url)
  print(df.head(4))
  plt.figure()
  sns.barplot(x=df['sex'],y=df['survived'])
	#sns.barplot(data=df,x='sex',y='survived',hue='survived') #easy method
  plt.show()


if __name__=="__main__":
  main()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
